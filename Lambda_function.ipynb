# %%
import numpy as np
import pandas as pd

# %%
f2=lambda x:"Nula" if x==0 else "Manji od 10" if x<10 else "Veći od 10"

# %%
f2(15)
# Out:
# 'Veći od 10'

# %%
f3=lambda x:"Jedan" if x==1 else "Dva" if x==2 else "Tri" if x==3 else "Četiri" if x==4 else "Drugo"

# %%
f3(15)
# Out:
# 'Drugo'
