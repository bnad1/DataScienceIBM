# %%
pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (3.16.0)
# Requirement already satisfied: ipython in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython-sql) (9.1.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (2.0.41)
# Requirement already satisfied: sqlparse in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\brunonad\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.13.2)
# Requirement already satisfied: colorama in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\brunonad\appdata\roaming\python\python311\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ucitavanje jer se zeli koristiti SQL magic 
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlite3

# %%
conn=sqlite3.connect('HR.db')

# %%
# %sql sqlite:///HR.db

# %%
# %sql SELECT * FROM Employee
# Out:
#  * sqlite:///HR.db
#    sqlite:///SQLiteMagic.db
# (sqlite3.OperationalError) no such table: Employee
# [SQL: SELECT * FROM Employee]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# #### Accessing Databases wit SQL Magic

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")
cur = con.cursor()

# %%
# %sql sqlite:///SQLiteMagic.db

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
#   country VARCHAR(50),
#   first_name VARCHAR(50),
#   last_name VARCHAR(50),
#   test_score INT
# );
#
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country,first_name,last_name,test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# (sqlite3.OperationalError) table INTERNATIONAL_STUDENT_TEST_SCORES already exists
# [SQL: CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
#   country VARCHAR(50),
#   first_name VARCHAR(50),
#   last_name VARCHAR(50),
#   test_score INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# !pip install ipython-sql prettytable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython-sql in c:\users\brunonad\appdata\roaming\python\python313\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\brunonad\appdata\roaming\python\python313\site-packages (3.16.0)
# Requirement already satisfied: ipython in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython-sql) (9.6.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython-sql) (2.0.44)
# Requirement already satisfied: sqlparse in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from prettytable) (0.2.14)
# Requirement already satisfied: greenlet>=1 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from stack_data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\brunonad\appdata\roaming\python\python313\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)

# %%
import prettytable

# %%
result=%sql SELECT test_score as "Test_Score", count(*) as "Freq" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score
# Out:
#    sqlite:///HR.db
#  * sqlite:///SQLiteMagic.db
# Done.

# %%
print(pd.DataFrame(result))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(result.DataFrame())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
