# %%
import pandas as pd 
import pandasql as ps
import numpy as np
import seaborn as sns

# %%
data_census=pd.read_csv(r"C:\Users\BrunoNad\Downloads\ChicagoCensusData.csv").dropna()
data_census
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 72                   73.0   Washington Height                         1.1
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
data_schools=pd.read_csv(r"C:\Users\BrunoNad\Downloads\ChicagoPublicSchools.csv").dropna()
data_schools
# Out:
#      School_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 5       610212                  Albany Park Multicultural Academy
# ..         ...                                                ...
# 560     610336         Williams Preparatory Academy Middle School
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
#
#     Elementary, Middle, or High School         Street_Address     City State  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
data_crime=pd.read_csv(r"C:\Users\BrunoNad\Desktop\DataScienceIBM\DataScienceIBM\ChicagoCrimeData.csv").dropna()
data_crime
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 527   9608166    HX258445  2014-05-12          010XX N WELLS ST  1900
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
# problem 1: Find the total number of crimes recorded in the CRIME table

ps.sqldf("SELECT COUNT(*) FROM data_crime")
# Out:
#    COUNT(*)
# 0       487

# %%
# problem 2: List community area names and numbers with per capita income less than 11000.

ps.sqldf("SELECT COMMUNITY_AREA_NAME,PER_CAPITA_INCOME FROM data_census WHERE PER_CAPITA_INCOME<11000")
# Out:
#   COMMUNITY_AREA_NAME  PER_CAPITA_INCOME
# 0  West Garfield Park              10934
# 1      South Lawndale              10402
# 2         Fuller Park              10432
# 3           Riverdale               8201

# %%
data_crime
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 527   9608166    HX258445  2014-05-12          010XX N WELLS ST  1900
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
data_crime.columns
# Out:
# Index(['ID', 'CASE_NUMBER', 'DATE', 'BLOCK', 'IUCR', 'PRIMARY_TYPE',
#        'DESCRIPTION', 'LOCATION_DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT',
#        'DISTRICT', 'WARD', 'COMMUNITY_AREA_NUMBER', 'FBICODE', 'X_COORDINATE',
#        'Y_COORDINATE', 'YEAR', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
data_crime['LOCATION_DESCRIPTION'].unique()
# Out:
# array(['SMALL RETAIL STORE', 'OTHER', 'NURSING HOME/RETIREMENT HOME',
#        'RESIDENCE', 'ALLEY', 'PARKING LOT/GARAGE(NON.RESID.)', 'STREET',
#        'GROCERY FOOD STORE', 'DEPARTMENT STORE', 'BAR OR TAVERN',
#        'RESIDENTIAL YARD (FRONT/BACK)', 'RESIDENCE PORCH/HALLWAY',
#        'CTA PLATFORM', 'VACANT LOT/LAND', 'SIDEWALK', 'ATHLETIC CLUB',
#        'AIRPORT/AIRCRAFT', 'APARTMENT', 'VEHICLE NON-COMMERCIAL',
#        'RESTAURANT', 'RESIDENCE-GARAGE', 'COMMERCIAL / BUSINESS OFFICE',
#        'TAVERN/LIQUOR STORE', 'CONSTRUCTION SITE', 'GAS STATION',
#        'DRUG STORE', 'CTA BUS', 'SCHOOL, PUBLIC, GROUNDS',
#        'SCHOOL, PUBLIC, BUILDING', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
#        'OTHER COMMERCIAL TRANSPORTATION', 'CHA APARTMENT',
#        'POLICE FACILITY/VEH PARKING LOT', 'HOSPITAL BUILDING/GROUNDS',
#        'FACTORY/MANUFACTURING BUILDING', 'CLEANING STORE', 'CTA TRAIN',
#        'BANK', 'CHA PARKING LOT/GROUNDS', 'LIBRARY',
# ...

# %%
# problem 3: List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# problem 4: List all kidnapping crimes involving a child?

# %%
# problem 5: List the kind of crimes that were recorded at schools. (No repetitions)

ps.sqldf("SELECT * FROM data_crime WHERE LOCATION_DESCRIPTION='SCHOOL, PUBLIC, BUILDING'")
# Out:
#         ID CASE_NUMBER        DATE                                BLOCK  IUCR  \
# 0  4430638    HL725506  2005-11-09                048XX N FRANCISCO AVE   484
# 1  6644618    HP716225  2008-12-04  030XX S DR MARTIN LUTHER KING JR DR   460
# 2  2341955    HH639427  2002-09-10                   005XX N WALLER AVE   460
# 3  7502426    HS305355  2010-05-13                035XX S WASHTENAW AVE  1821
#
#   PRIMARY_TYPE                     DESCRIPTION      LOCATION_DESCRIPTION  \
# 0      BATTERY     PRO EMP HANDS NO/MIN INJURY  SCHOOL, PUBLIC, BUILDING
# 1      BATTERY                          SIMPLE  SCHOOL, PUBLIC, BUILDING
# 2      BATTERY                          SIMPLE  SCHOOL, PUBLIC, BUILDING
# 3    NARCOTICS  MANU/DEL:CANNABIS 10GM OR LESS  SCHOOL, PUBLIC, BUILDING
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# 0       1         0  ...        20  40.0                    4.0      08B
# ...

# %%
# problem 6: List the type of schools along with the average safety score for each type

ps.sqldf("SELECT NAME_OF_SCHOOL,SAFETY_SCORE FROM data_schools")
# Out:
#                                         NAME_OF_SCHOOL  SAFETY_SCORE
# 0                    Abraham Lincoln Elementary School          99.0
# 1    Adam Clayton Powell Paideia Community Academy ...          54.0
# 2                  Adlai E Stevenson Elementary School          61.0
# 3                      Agustin Lara Elementary Academy          56.0
# 4                    Albany Park Multicultural Academy          66.0
# ..                                                 ...           ...
# 431         Williams Preparatory Academy Middle School          49.0
# 432                William T Sherman Elementary School          32.0
# 433                 William W Carter Elementary School          13.0
# 434                Wolfgang A Mozart Elementary School          41.0
# 435               Woodlawn Community Elementary School          70.0
#
# [436 rows x 2 columns]

# %%
# problem 7: List 5 community areas with highest % of households below poverty line
